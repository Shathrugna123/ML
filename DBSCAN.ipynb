# %% [markdown]
# <a href="https://colab.research.google.com/github/Shathrugna123/ML/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt

# Sample Data
X = np.array([[1, 2], [2, 3], [2, 2], [8, 7], [8, 8], [25, 80]])

# DBSCAN clustering
db = DBSCAN(eps=3, min_samples=2).fit(X)
labels = db.labels_

# Visualize
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
